# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * 1.1 Вывести на экран первые 5 строк

# %%
hd = pd.read_csv('./kc_house_data2.csv')
hd.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# * 1.2 Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома. Если реновации дома не было, то в новом признаке поставьте 0

# %%
hd['delta_renovated'] = 0
hd.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
hd['delta_renovated'] = hd['yr_renovated'] - hd['yr_built']
hd.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
hd['delta_renovated'] = hd['yr_renovated'] - hd['yr_built']

if hd['delta_renovated'] < 0:
    hd['delta_renovated'] == 0
    

hd.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24260\4086538002.py in <module>
#       1 hd['delta_renovated'] = hd['yr_renovated'] - hd['yr_built']
#       2
# ----> 3 if hd['delta_renovated'] < 0:
#       4     hd['delta_renovated'] == 0
#       5
#
# ~\anaconda\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ### <font color='red'> Не понял, как заполнить заменить отрицательные зачения</font>

# %% [markdown]
# * 1.3 Создайте признаки года продажи, месяца продажи

# %%
hd['sale_year'] = 0
hd.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
hd['sale_month'] = 0
hd.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
# ...

# %% [markdown]
# * 1.4 Удалите признаки date, zipcode, lat, long

# %%
hd.drop(columns =['date', 'zipcode', 'lat', 'long'], inplace = True)
hd.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %% [markdown]
# ## Задача 2
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
# 'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
# 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
# 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
# 'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
# 1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
# 5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
# 5083000375, 7920100025, 1951600150, 809001400, 339600110,
# 1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
# 8861700030, 3303980210, 7731100066, 8146100580, 825069097,
# 3889100029, 9524100196]
# })

# %%
clients = pd.DataFrame({ 
    'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765,
                  1472, 4236, 2295, 939, 3840, 280, 20, 4332,
                  3475, 4213, 3113, 4809, 2134, 2242, 2068, 4929,
                  1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
    'house_id': [8965450190, 6823100225, 5104540330, 2131701075,
                 1522700060, 1189000207, 6821600300, 7137950720,
                 9510920050, 6131600255, 5428000070, 1788800910,
                 8100400160, 3123049142, 6306800010, 5083000375,
                 7920100025, 1951600150, 809001400, 339600110,
                 1622049154, 1099600250, 8563000110, 2768100205,
                 3995700435, 8861700030, 3303980210, 7731100066,
                 8146100580, 825069097, 3889100029, 9524100196] })
clients.head()
# Out:
#    client_id    house_id
# 0       1459  8965450190
# 1       4684  6823100225
# 2       3498  5104540330
# 3       3942  2131701075
# 4       4535  1522700060

# %%
clients.shape
# Out:
# (32, 2)

# %% [markdown]
# * 2.1 Присоедините к таблице clients данные по домам через метод join

# %%
hd_id = hd.set_index('id')
hd_id.head()
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id
# 7129300520  221900.0         3       1.00         1180      5650     1.0
# 6414100192  538000.0         3       2.25         2570      7242     2.0
# 5631500400  180000.0         2       1.00          770     10000     1.0
# 2487200875  604000.0         4       3.00         1960      5000     1.0
# 1954400510  510000.0         3       2.00         1680      8080     1.0
#
#             waterfront  view  condition  grade  sqft_above  sqft_basement  \
# id
# 7129300520           0     0          3      7        1180              0
# 6414100192           0     0          3      7        2170            400
# 5631500400           0     0          3      6         770              0
# 2487200875           0     0          5      7        1050            910
# 1954400510           0     0          3      8        1680              0
#
#             yr_built  yr_renovated  sqft_living15  sqft_lot15  \
# id
# ...

# %%
clients_id = clients.set_index('client_id')
clients_id.head()
# Out:
#              house_id
# client_id
# 1459       8965450190
# 4684       6823100225
# 3498       5104540330
# 3942       2131701075
# 4535       1522700060

# %%
hd_id.join(clients_id).head()
# Out:
#             price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1000102  280000.0         6       3.00         2400      9373     2.0
# 1000102  300000.0         6       3.00         2400      9373     2.0
# 1200019  647500.0         4       1.75         2060     26036     1.0
# 1200021  400000.0         3       1.00         1460     43000     1.0
# 2800031  235000.0         3       1.00         1430      7599     1.5
#
#          waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 1000102           0     0          3      7        2400              0
# 1000102           0     0          3      7        2400              0
# 1200019           0     0          4      8        1160            900
# 1200021           0     0          3      7        1460              0
# 2800031           0     0          4      6        1010            420
#
#          yr_built  yr_renovated  sqft_living15  sqft_lot15  delta_renovated  \
# ...

# %% [markdown]
# * 2.2 Присоедините к таблице clients данные по домам через метод merge. Это нужно, чтобы понимать, какие дома покупались клиентами. house_id - это индексы датафрейма с домами

# %%
merged = hd.merge(clients, left_on='id', right_on='house_id')
merged
# Out:
#             id      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0   8100400160   700000.0         3       2.25         2330     11424     2.0
# 1   7920100025   450000.0         2       1.00          740      5100     1.0
# 2    825069097   770000.0         3       2.50         2650     40705     2.0
# 3   5083000375   170000.0         3       1.00         1310      9529     1.0
# 4   5083000375   235000.0         3       1.00         1310      9529     1.0
# 5    339600110   395000.0         3       2.50         1610      3755     2.0
# 6   6821600300   886000.0         3       2.25         2380      6000     2.0
# 7   1099600250   260000.0         3       1.75         1710      6400     1.0
# 8   3889100029   810000.0         3       2.50         2670     10481     2.0
# 9   3123049142   452000.0         3       2.25         2600     14810     1.0
# 10  8965450190   295000.0         3       2.50         1500      3060     2.0
# ...

# %% [markdown]
# ## Задача3
# Составьте несколько сводных таблиц

# %% [markdown]
# * 3.1 Найдите среднюю стоимость домов в зависимости от количества спален.
# Отсортируйте от меньшей стоимости к большей

# %%
merged.groupby('bedrooms').agg({'price':['mean']})
# Out:
#                   price
#                    mean
# bedrooms
# 2         358666.666667
# 3         486270.000000
# 4         555396.888889
# 5         770000.000000

# %% [markdown]
# * 3.2 Найдите минимальную, среднюю и максимальную стоимости домов в зависимости от состояния дома

# %%
merged.groupby('condition').agg({'price':['min', 'mean', 'max']})
# Out:
#               price
#                 min           mean        max
# condition
# 3          170000.0  490445.894737  1115000.0
# 4          190000.0  496636.363636   925000.0
# 5          202500.0  596166.666667   886000.0

# %% [markdown]
# * 3.3 Постройте таблицу с подсчетом количества домов в данных в зависимости от вида на набережную и оценкой вида

# %%
merged[(merged['waterfront'] > 0) | (merged['view']) > 0]
# Out:
#             id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 9   3123049142  452000.0         3       2.25         2600     14810     1.0
# 31  5428000070  770000.0         5       3.50         4750      8234     2.0
#
#     waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 9            0     2          4  ...           1110      1956             0
# 31           0     2          3  ...           1400      2013             0
#
#     sqft_living15  sqft_lot15  delta_renovated  sale_year  sale_month  \
# 9            2450       16715                0          0           0
# 31           2160       14496                0          0           0
#
#     client_id    house_id
# 9         280  3123049142
# 31       2295  5428000070
#
# [2 rows x 22 columns]

# %% [markdown]
# * 3.4 Каких домов в зависимости от этажности и количества спален больше?

# %%
pd.crosstab(index = merged['bedrooms'],
           columns = ['floors'])
# Out:
# col_0     floors
# bedrooms
# 2              3
# 3             20
# 4              9
# 5              1

# %% [markdown]
# * 3.5 Постройте таблицу с подсчетом медианной стоимости домов в данных в зависимости от состояния дома и оценки дома

# %%
merged.pivot_table(index = 'condition',
                  columns = 'grade',
                  values = 'price',
                  aggfunc = 'mean',
                  margins=True,
                  margins_name='total')
# Out:
# grade             6              7              8         9             10  \
# condition
# 3               NaN  293612.500000  382033.333333  633618.0  724666.666667
# 4          190000.0  447666.666667  646750.000000       NaN            NaN
# 5          202500.0            NaN  700000.000000  886000.0            NaN
# total      196250.0  359635.714286  554137.500000  684094.4  724666.666667
#
# grade             11          total
# condition
# 3          1115000.0  490445.894737
# 4                NaN  496636.363636
# 5                NaN  596166.666667
# total      1115000.0  502120.363636

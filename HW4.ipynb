# %%
import pandas as pd
import numpy as np

# %% [markdown]
# * 1.1. Скачать данные по ссылке https://www.kaggle.com/datasets/esratmaria/house-price-dataset-with-other-information

# %%
hd = pd.read_csv('./kc_house_data.csv', sep=',')
hd
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# * Постройте график

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(7, 5))
plt.plot([0, 1, 2, 3], [16, 9, 4, 1])
plt.grid();

# %% [markdown]
# * Назовите график

# %%
plt.figure(figsize=(7, 5))
plt.plot([0, 1, 2, 3], [16, 9, 4, 1])
plt.title('Testgraph')
plt.grid();

# %% [markdown]
# * Сделайте именование оси x и оси y

# %%
plt.figure(figsize=(7, 5))
plt.plot([0, 1, 2, 3], [16, 9, 4, 1])
plt.title('Testgraph')
plt.grid();
plt.xlabel('Ось X')
plt.ylabel('Ось Y');

# %% [markdown]
# * Сделайте выводы

# %% [markdown]
# _Строить графики в ноутбуке достаточно просто_

# %% [markdown]
# * 1.2 Изучите стоимости недвижимости

# %%
hd['price'].value_counts()
# Out:
# 350000.0     172
# 450000.0     172
# 550000.0     159
# 500000.0     152
# 425000.0     150
#             ...
# 607010.0       1
# 1362500.0      1
# 298800.0       1
# 957500.0       1
# 402101.0       1
# Name: price, Length: 4028, dtype: int64

# %%
plt.figure(figsize=(10, 5))

plt.hist(hd['price'],bins = 10)
plt.title('Стоимость недвижимости')
plt.xlabel('Цены')
plt.ylabel('Дома');

# %% [markdown]
# * 1.3 Изучите распределение квадратуры жилой

# %%
hd['sqft_living'].value_counts()
# Out:
# 1300    138
# 1400    135
# 1440    133
# 1800    129
# 1660    129
#        ...
# 9890      1
# 5584      1
# 1961      1
# 5720      1
# 1425      1
# Name: sqft_living, Length: 1038, dtype: int64

# %%
plt.figure(figsize=(20, 5))

plt.hist(hd['sqft_living'],bins = 50)
plt.title('Стоимость недвижимости')
plt.xlabel('Квадратура жилой площади')
plt.ylabel('Дома');

# %% [markdown]
# * 2.1.4 Изучите распределение года постройки

# %%
hd['yr_built'].value_counts()
# Out:
# 2014    559
# 2006    454
# 2005    450
# 2004    433
# 2003    422
#        ...
# 1933     30
# 1901     29
# 1902     27
# 1935     24
# 1934     21
# Name: yr_built, Length: 116, dtype: int64

# %%
plt.figure(figsize=(20, 5))

sns.histplot(hd['yr_built'],bins = 50)
plt.title('Стоимость недвижимости')
plt.xlabel('Квадратура жилой площади')
plt.ylabel('Дома');

# %% [markdown]
# ## Задача 2
#
# * 2.1 Изучите распределение домов от наличия вида на набережную
#
#  - Постройте график
#
#  - Сделайте выводы

# %%
wf = hd['waterfront'].value_counts().reset_index()
wf
# Out:
#    index  waterfront
# 0      0       21450
# 1      1         163

# %%
plt.figure(figsize=(7, 5))

sns.barplot(x = wf['waterfront'], y = wf['index'])
plt.title('Распределение домов от наличия вида на набережную')
plt.xlabel('Вид на набережную')
plt.ylabel('Дома')
plt.xticks(rotation = 0);

# %% [markdown]
# ## Задача 3
# * Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока. Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.

# %%
plt.figure(figsize=(10, 5))

plt.hist(hd['price'])
plt.title('Стоимость недвижимости')
plt.xlabel('Цены')
plt.ylabel('Дома');

# %%
hd_features = hd.select_dtypes(include=['int64', 'float64'])
hd_features.drop(['price', 'id', 'sqft_lot', 'waterfront', 'yr_renovated',
                 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
                 axis = 1, inplace=True)

# %%
hd_features.hist(figsize=(16, 16), bins = 20, grid = False);

# %% [markdown]
# _Стоимость домов сильно зависит от года постройки, наличия, спален, ванных комнат и других показателей_
